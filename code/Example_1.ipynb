# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("/home/parag/ml-notes-and-code/data/sample_dataset.csv")

# %%
df
# Out:
#    area   price
# 0  3000  550000
# 1  3200  565000
# 2  3600  680000
# 3  4000  725000
# 4  2600  540000

# %%
# %matplotlib inline
plt.scatter(df.area,df.price)
plt.show()

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
expected_value = 148.28767123 * 3300 + 125616.4383561645
print(f"Expected value: {expected_value}")
# Out:
# Expected value: 614965.7534151645

# %%
predicted_value = reg.predict([[3300]])[0]
print(f"Model prediction: {predicted_value}")
# Out:
# Model prediction: 614965.7534246575
# /home/parag/ml-notes-and-code/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.coef_
# Out:
# array([148.28767123])

# %%
reg.intercept_
# Out:
# np.float64(125616.4383561645)

# %%
reg.predict([[5000]])
# Out:
# /home/parag/ml-notes-and-code/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([867054.79452055])

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.area, df.price,color='red')
plt.plot(df.area,reg.predict(df[['area']]))
plt.show()
